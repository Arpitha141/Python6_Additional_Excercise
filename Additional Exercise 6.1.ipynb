# %% [markdown]
# ## Get Data from the following link:
#
# http://files.grouplens.org/datasets/movielens/ml-20m.zip
#
# #### We will be using the following files for this exercise:
# ratings.csv : userId,movieId,rating, timestamp
# tags.csv : userId,movieId, tag, timestamp
# movies.csv : movieId, title, genres

# %% [markdown]
# #### 1. Read the dataset using pandas.

# %%
import pandas as pd                                                 # Importing the  pandas and os packages
import os

# %%
! wget http://files.grouplens.org/datasets/movielens/ml-20m.zip    # To retrieve the zip file from website
! unzip ml-20m.zip                                                 # Unzipng the zip file
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
ratings = pd.read_csv('C:\\Users\\Arpitha\\Documents\\Lerning_Material\\Assignments\\Pandas 2\\Additional Exercise 6.1\\ml-20m\\ratings.csv', sep=',')          # Reading the three CSV files (rating, tags, movies)

# %%
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
tags = pd.read_csv('C:\\Users\\Arpitha\\Documents\\Lerning_Material\\Assignments\\Pandas 2\\Additional Exercise 6.1\\ml-20m\\tags.csv', sep=',')
`

# %%
tags.head()
# Out:
#    userId  movieId            tag   timestamp
# 0      18     4141    Mark Waters  1240597180
# 1      65      208      dark hero  1368150078
# 2      65      353      dark hero  1368150079
# 3      65      521  noir thriller  1368149983
# 4      65      592      dark hero  1368150078

# %%
movies = pd.read_csv('C:\\Users\\Arpitha\\Documents\\Lerning_Material\\Assignments\\Pandas 2\\Additional Exercise 6.1\\ml-20m\\movies.csv', sep=',')

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# #### 2. Extract the first row from tags and print its type.

# %%
firstrow=tags.iloc[0]              # extracting the first row based upon index value
print("Type is: ",type(firstrow))     #  Displaying the type of first row
firstrow
# Out:
# Type is:  <class 'pandas.core.series.Series'>
# userId                18
# movieId             4141
# tag          Mark Waters
# timestamp     1240597180
# Name: 0, dtype: object

# %% [markdown]
# #### 3. Extract row 0, 11, 2000 from tags DataFrame.

# %%
tags.iloc[[0,11,2000]]      # Extracting the rows basedup on index values
# Out:
#       userId  movieId                tag   timestamp
# 0         18     4141        Mark Waters  1240597180
# 11        65     1783      noir thriller  1368149983
# 2000     910    68554  conspiracy theory  1368043943

# %% [markdown]
# #### 4. Print index, columns of the DataFrame.

# %%
# for Tags Data Frame
print("Index for Tags data frame  : ",tags.index)           # Extracting the Index information of tags
print("Columns for Tags data frame: ",tags.columns)         # Extracting the columns information of tags
# Out:
# Index for Tags data frame  :  RangeIndex(start=0, stop=465564, step=1)
# Columns for Tags data frame:  Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
# for Tags Data Frame
print("Index for Ratings data frame  : ",ratings.index)     # Extracting the Index information of ratings
print("Columns for Ratings data frame: ",ratings.columns)   # Extracting the column information of ratings
# Out:
# Index for Ratings data frame  :  RangeIndex(start=0, stop=20000263, step=1)
# Columns for Ratings data frame:  Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
# for Tags Data Frame
print("Index for Movies data frame  : ",movies.index)       # Extracting the Index information of Movies
print("Columns for Movies data frame: ",movies.columns)     # Extracting the column information of Movies
# Out:
# Index for Movies data frame  :  RangeIndex(start=0, stop=27278, step=1)
# Columns for Movies data frame:  Index(['movieId', 'title', 'genres'], dtype='object')

# %% [markdown]
# ### 5. Calculate descriptive statistics for the 'ratings' column of the ratings DataFrame. Verify using describe().

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
#count
ratings["rating"].count()
# Out:
# 20000263

# %%
#Mean 
ratings["rating"].mean()
# Out:
# 3.5255285642993797

# %%
#Standard Deviation '
ratings["rating"].std()
# Out:
# 1.051988919275684

# %%
#minmum
ratings["rating"].min()
# Out:
# 0.5

# %%
#25 Percentile
ratings["rating"].quantile(0.25)
# Out:
# 3.0

# %%
#50 Percentile
ratings["rating"].quantile(0.50)
# Out:
# 3.5

# %%
#75 Percentile
ratings["rating"].quantile(0.75)
# Out:
# 4.0

# %%
#maximum 
ratings["rating"].max()
# Out:
# 5.0

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating     timestamp
# count  2.000026e+07  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00  1.100918e+09
# std    4.003863e+04  1.978948e+04  1.051989e+00  1.621694e+08
# min    1.000000e+00  1.000000e+00  5.000000e-01  7.896520e+08
# 25%    3.439500e+04  9.020000e+02  3.000000e+00  9.667977e+08
# 50%    6.914100e+04  2.167000e+03  3.500000e+00  1.103556e+09
# 75%    1.036370e+05  4.770000e+03  4.000000e+00  1.225642e+09
# max    1.384930e+05  1.312620e+05  5.000000e+00  1.427784e+09

# %% [markdown]
# ### 6. Filter out ratings with rating > 5

# %%
ratings[ratings["rating"]>5]                         # Filtering the data based up on rating >5 condition
# Out:
# Empty DataFrame
# Columns: [userId, movieId, rating, timestamp]
# Index: []

# %% [markdown]
# ### 7. Find how many null values, missing values are present. Deal with them. Print out how many rows have been modified.

# %%
print("nulls values information in ratings")
ratingNulls=ratings.isna().sum()                             # Calculating the null values in each column of rating dataframe
print(ratingNulls)

print("\nnulls values information in tags")
tagsNulls=tags.isna().sum()                                 # Calculating the null values in each column of tags dataframe
print(tagsNulls)
tagsshapeb4=tags.shape
print("\nnulls values information in movies")
moviesNulls=movies.isna().sum()                             # Calculating the null values in each column of Movies dataframe
print(moviesNulls)

print("number of null values in ratings are ",ratingNulls.sum())  # Dsiplaying the total count of null values in rating dataframe
print("number of null values in tags are ",tagsNulls.sum())       # Dsiplaying the total count of null values in tags dataframe
print("number of null values in movies are ",moviesNulls.sum())   # Dsiplaying the total count of null values in movies dataframe

tags = tags.dropna()                                        # Dropping the null values present in the tags
tagsshapebaftr=tags.shape
print("number of rows modified in tags are ",int(tagsshapeb4[0])-int(tagsshapebaftr[0]))     # Numebr of rows modified in the tags dataframe
# Out:
# nulls values information in ratings
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
#
# nulls values information in tags
# userId        0
# movieId       0
# tag          16
# timestamp     0
# dtype: int64
#
# nulls values information in movies
# movieId    0
# title      0
# genres     0
# dtype: int64
# number of null values in ratings are  0
# number of null values in tags are  16
# number of null values in movies are  0
# number of rows modified in tags are  16

# %% [markdown]
# #### 8. Filter out movies from the movies DataFrame that are of type 'Animation'.

# %%
# Filtering the movies based up on Animation 
Animation=movies[movies["genres"].str.contains('Animation',case = False)]
movieTitles = Animation["title"]                  # Storing the movie titles into movieTitles
movieTitles=movieTitles.reset_index(drop=True)      # Reseting the index
movieTitles=pd.DataFrame(movieTitles)               # Converting into dataframe
movieTitles
# Out:
#                                                   title
# 0                                      Toy Story (1995)
# 1                                          Balto (1995)
# 2                                     Pocahontas (1995)
# 3                                 Goofy Movie, A (1995)
# 4                               Gumby: The Movie (1995)
# 5                             Swan Princess, The (1994)
# 6                                 Lion King, The (1994)
# 7            Secret Adventures of Tom Thumb, The (1993)
# 8                Nightmare Before Christmas, The (1993)
# 9                                Pagemaster, The (1994)
# 10                                       Aladdin (1992)
# 11               Snow White and the Seven Dwarfs (1937)
# 12                          Beauty and the Beast (1991)
# 13                                     Pinocchio (1940)
# 14                                   Heavy Metal (1981)
# 15                               Aristocats, The (1970)
# 16                       All Dogs Go to Heaven 2 (1996)
# 17                     James and the Giant Peach (1996)
# 18                                     Space Jam (1996)
# 19                              Oliver & Company (1988)
# 20    Wallace & Gromit: The Best of Aardman Animatio...
# 21           Ghost in the Shell (Kôkaku kidôtai) (1995)
# 22               Wallace & Gromit: A Close Shave (1995)
# 23                  Hunchback of Notre Dame, The (1996)
# 24    Land Before Time III: The Time of the Great Gi...
# 25                                    Cinderella (1950)
# 26          Winnie the Pooh and the Blustery Day (1968)
# 27                         Three Caballeros, The (1945)
# 28                       Sword in the Stone, The (1963)
# 29                                         Dumbo (1941)
# ...                                                 ...
# 997                               Animals United (2011)
# 998               Tom and Jerry: The Lost Dragon (2014)
# 999      Mardock Scramble: The Second Combustion (2011)
# 1000                        Stand by Me Doraemon (2014)
# 1001                                Frozen Fever (2015)
# 1002                                  The Mascot (1934)
# 1003          Cardcaptor Sakura: The Sealed Card (2000)
# 1004  Berserk: The Golden Age Arc 2 - The Battle for...
# 1005  Berserk: The Golden Age Arc - The Egg of the K...
# 1006     Berserk: The Golden Age Arc 3 - Descent (2013)
# 1007                   The Amazing Screw-On Head (2006)
# 1008                                        Home (2015)
# 1009       The Brave Little Toaster Goes to Mars (1998)
# 1010  The Garden of Sinners - Chapter 5: Paradox Par...
# 1011                          Santa's Apprentice (2010)
# 1012                         Ronal the Barbarian (2011)
# 1013             Cinderella III: A Twist in Time (2007)
# 1014  The Little Polar Bear: Lars and the Little Tig...
# 1015  Mickey, Donald, Goofy: The Three Musketeers (2...
# 1016   Rudolph the Red-Nosed Reindeer: The Movie (1998)
# 1017                                Saving Santa (2013)
# 1018       Lucky Luke: The Ballad of the Daltons (1978)
# 1019                  Casper's Haunted Christmas (2000)
# 1020                             Superstar Goofy (1991)
# 1021            Tom and Jerry: A Nutcracker Tale (2007)
# 1022                Kleines Arschloch - Der Film (1997)
# 1023                Werner - Das muss kesseln!!! (1996)
# 1024                      Werner - Volles Rooäää (1999)
# 1025                Werner - Gekotzt wird später (2003)
# 1026                              Brother Bear 2 (2006)
#
# [1027 rows x 1 columns]

# %% [markdown]
# ### 9. Find the average rating of movies.

# %%
avg = ratings.groupby('movieId').mean()            # grouping the ratings data frame basedon movieID and calculating the mean/average
ratingCol=avg["rating"]                            # Storing the rating column into df_ratingCol
avgMovies=pd.DataFrame(ratingCol)                  # Converting into dataframe
avgMovies.sort_values("rating",ascending=False)       # Sorting the movies based in descending order
# Out:
#          rating
# movieId
# 95517       5.0
# 105846      5.0
# 89133       5.0
# 105187      5.0
# 105191      5.0
# 88488       5.0
# 126945      5.0
# 105526      5.0
# 105529      5.0
# 105841      5.0
# 126397      5.0
# 103912      5.0
# 126219      5.0
# 106082      5.0
# 106113      5.0
# 106115      5.0
# 125599      5.0
# 106517      5.0
# 107252      5.0
# 86055       5.0
# 104317      5.0
# 127256      5.0
# 122441      5.0
# 92783       5.0
# 129478      5.0
# 129352      5.0
# 129305      5.0
# 92956       5.0
# 129295      5.0
# 129293      5.0
# ...         ...
# 103923      0.5
# 93583       0.5
# 59775       0.5
# 97915       0.5
# 97847       0.5
# 129871      0.5
# 124302      0.5
# 112782      0.5
# 112780      0.5
# 124368      0.5
# 112778      0.5
# 112776      0.5
# 123314      0.5
# 103769      0.5
# 85694       0.5
# 103695      0.5
# 114093      0.5
# 98080       0.5
# 103614      0.5
# 129456      0.5
# 93083       0.5
# 122930      0.5
# 122595      0.5
# 103294      0.5
# 129701      0.5
# 129784      0.5
# 92479       0.5
# 129834      0.5
# 115631      0.5
# 119909      0.5
#
# [26744 rows x 1 columns]

# %% [markdown]
# #### 10. Perform an inner join of movies and tags based on movieId.

# %%
merge=movies.merge(tags, on='movieId', how='inner')   # Performing the inner join on movies and tags basedon movieId
merge
# Out:
#         movieId                                          title  \
# 0             1                               Toy Story (1995)
# 1             1                               Toy Story (1995)
# 2             1                               Toy Story (1995)
# 3             1                               Toy Story (1995)
# 4             1                               Toy Story (1995)
# 5             1                               Toy Story (1995)
# 6             1                               Toy Story (1995)
# 7             1                               Toy Story (1995)
# 8             1                               Toy Story (1995)
# 9             1                               Toy Story (1995)
# 10            1                               Toy Story (1995)
# 11            1                               Toy Story (1995)
# 12            1                               Toy Story (1995)
# 13            1                               Toy Story (1995)
# 14            1                               Toy Story (1995)
# 15            1                               Toy Story (1995)
# 16            1                               Toy Story (1995)
# 17            1                               Toy Story (1995)
# 18            1                               Toy Story (1995)
# 19            1                               Toy Story (1995)
# 20            1                               Toy Story (1995)
# 21            1                               Toy Story (1995)
# 22            1                               Toy Story (1995)
# 23            1                               Toy Story (1995)
# 24            1                               Toy Story (1995)
# 25            1                               Toy Story (1995)
# 26            1                               Toy Story (1995)
# 27            1                               Toy Story (1995)
# 28            1                               Toy Story (1995)
# 29            1                               Toy Story (1995)
# ...         ...                                            ...
# 465518   131015                                Hellgate (2011)
# 465519   131015                                Hellgate (2011)
# 465520   131015                                Hellgate (2011)
# 465521   131015                                Hellgate (2011)
# 465522   131015                                Hellgate (2011)
# 465523   131015                                Hellgate (2011)
# 465524   131015                                Hellgate (2011)
# 465525   131015                                Hellgate (2011)
# 465526   131015                                Hellgate (2011)
# 465527   131015                                Hellgate (2011)
# 465528   131015                                Hellgate (2011)
# 465529   131015                                Hellgate (2011)
# 465530   131031           La liga no es cosa de hombres (1972)
# 465531   131031           La liga no es cosa de hombres (1972)
# 465532   131031           La liga no es cosa de hombres (1972)
# 465533   131031           La liga no es cosa de hombres (1972)
# 465534   131031           La liga no es cosa de hombres (1972)
# 465535   131031           La liga no es cosa de hombres (1972)
# 465536   131031           La liga no es cosa de hombres (1972)
# 465537   131031           La liga no es cosa de hombres (1972)
# 465538   131054  Dinotopia: Quest for the Ruby Sunstone (2005)
# 465539   131082                              Playground (2009)
# 465540   131082                              Playground (2009)
# 465541   131164                           Vietnam in HD (2011)
# 465542   131170                               Parallels (2015)
# 465543   131258                             The Pirates (2014)
# 465544   131258                             The Pirates (2014)
# 465545   131258                             The Pirates (2014)
# 465546   131258                             The Pirates (2014)
# 465547   131258                             The Pirates (2014)
#
#                                              genres  userId  \
# 0       Adventure|Animation|Children|Comedy|Fantasy    1644
# 1       Adventure|Animation|Children|Comedy|Fantasy    1741
# 2       Adventure|Animation|Children|Comedy|Fantasy    1741
# 3       Adventure|Animation|Children|Comedy|Fantasy    1741
# 4       Adventure|Animation|Children|Comedy|Fantasy    1741
# 5       Adventure|Animation|Children|Comedy|Fantasy    2299
# 6       Adventure|Animation|Children|Comedy|Fantasy    3596
# 7       Adventure|Animation|Children|Comedy|Fantasy    3596
# 8       Adventure|Animation|Children|Comedy|Fantasy    3596
# 9       Adventure|Animation|Children|Comedy|Fantasy    6233
# 10      Adventure|Animation|Children|Comedy|Fantasy    6233
# 11      Adventure|Animation|Children|Comedy|Fantasy    8219
# 12      Adventure|Animation|Children|Comedy|Fantasy   10616
# 13      Adventure|Animation|Children|Comedy|Fantasy   10616
# 14      Adventure|Animation|Children|Comedy|Fantasy   10616
# 15      Adventure|Animation|Children|Comedy|Fantasy   10616
# 16      Adventure|Animation|Children|Comedy|Fantasy   10616
# 17      Adventure|Animation|Children|Comedy|Fantasy   10616
# 18      Adventure|Animation|Children|Comedy|Fantasy   10616
# 19      Adventure|Animation|Children|Comedy|Fantasy   10616
# 20      Adventure|Animation|Children|Comedy|Fantasy   10616
# 21      Adventure|Animation|Children|Comedy|Fantasy   11081
# 22      Adventure|Animation|Children|Comedy|Fantasy   11081
# 23      Adventure|Animation|Children|Comedy|Fantasy   11081
# 24      Adventure|Animation|Children|Comedy|Fantasy   11081
# 25      Adventure|Animation|Children|Comedy|Fantasy   11081
# 26      Adventure|Animation|Children|Comedy|Fantasy   11081
# 27      Adventure|Animation|Children|Comedy|Fantasy   11081
# 28      Adventure|Animation|Children|Comedy|Fantasy   11081
# 29      Adventure|Animation|Children|Comedy|Fantasy   11081
# ...                                             ...     ...
# 465518                              Horror|Thriller   25978
# 465519                              Horror|Thriller   25978
# 465520                              Horror|Thriller   25978
# 465521                              Horror|Thriller   25978
# 465522                              Horror|Thriller   25978
# 465523                              Horror|Thriller   25978
# 465524                              Horror|Thriller   25978
# 465525                              Horror|Thriller   25978
# 465526                              Horror|Thriller   25978
# 465527                              Horror|Thriller   25978
# 465528                              Horror|Thriller   25978
# 465529                              Horror|Thriller   25978
# 465530                           (no genres listed)   33323
# 465531                           (no genres listed)   33323
# 465532                           (no genres listed)   33323
# 465533                           (no genres listed)   33323
# 465534                           (no genres listed)   33323
# 465535                           (no genres listed)   33323
# 465536                           (no genres listed)   33323
# 465537                           (no genres listed)   33323
# 465538                      Children|Fantasy|Sci-Fi   88144
# 465539                           (no genres listed)   92885
# 465540                           (no genres listed)   92885
# 465541                                          War   54560
# 465542                                       Sci-Fi   88738
# 465543                                    Adventure   28906
# 465544                                    Adventure   28906
# 465545                                    Adventure   28906
# 465546                                    Adventure   28906
# 465547                                    Adventure   28906
#
#                                            tag   timestamp
# 0                                      Watched  1417736680
# 1                           computer animation  1183903155
# 2                      Disney animated feature  1183933307
# 3                              Pixar animation  1183934770
# 4       TÃ©a Leoni does not star in this movie  1245093573
# 5                                        Pixar  1403306852
# 6                                    animation  1290312028
# 7                                       family  1290312032
# 8                                    Tom Hanks  1290312036
# 9                                        Pixar  1387079572
# 10                                       witty  1387079576
# 11                                       Pixar  1159534063
# 12                                   adventure  1277357423
# 13                                    animated  1277357419
# 14                                   animation  1277357417
# 15                                      clever  1277357438
# 16                                      comedy  1277357433
# 17                          computer animation  1277357405
# 18                                      family  1277357449
# 19                                     fantasy  1277357430
# 20                                   Tom Hanks  1277357411
# 21                                      bright  1173304070
# 22                              DARING RESCUES  1173304095
# 23                                    fanciful  1173304058
# 24                              HEROIC MISSION  1173304102
# 25                                    humorous  1173304049
# 26                                       light  1173304062
# 27                                     rousing  1173304074
# 28                           TOYS COME TO LIFE  1173304091
# 29                        UNLIKELY FRIENDSHIPS  1173304106
# ...                                        ...         ...
# 465518                              Cary Elwes  1427585540
# 465519                                  Demons  1427585566
# 465520                                Exorcism  1427585551
# 465521                                  Ghosts  1427585546
# 465522                                   Monks  1427585560
# 465523                                   nurse  1427585621
# 465524                                 psychic  1427585613
# 465525                                    slow  1427585575
# 465526                         special effects  1427585690
# 465527                                 surfing  1427585592
# 465528                                Thailand  1427585543
# 465529                            William Hurt  1427585696
# 465530                               Barcelona  1427641562
# 465531                            exploitation  1427641559
# 465532                         female football  1427641577
# 465533                                football  1427641548
# 465534                                    Rome  1427641564
# 465535                                  shorts  1427641571
# 465536                                  soccer  1427641556
# 465537                            transvestite  1427641589
# 465538                               dinosaurs  1427654430
# 465539                             documentary  1427654757
# 465540                          Yoshitomo Nara  1427654856
# 465541                             Vietnam War  1427667401
# 465542                       alternate reality  1427732804
# 465543                                 bandits  1427745421
# 465544                                   Korea  1427745512
# 465545                                  mutiny  1427745542
# 465546                                 pirates  1427745419
# 465547                                   whale  1427745432
#
# [465548 rows x 6 columns]

# %% [markdown]
# #### 11. Print out the 5 movies that belong to the Comedy genre and have rating greater than 4.

# %%
df_avg = ratings.groupby('movieId').mean()                                   # 
df_AvgGr4=avg[df_avg["rating"]>4]
df_temp=movies.merge(df_AvgGr4, on='movieId', how='inner')
df_ComedyGr4=df_temp[df_temp["genres"].str.contains('Comedy',case = False)]
df_ComedyGr4.head()
# Out:
#     movieId                                        title  \
# 3        82              Antonia's Line (Antonia) (1995)
# 9       232  Eat Drink Man Woman (Yin shi nan nu) (1994)
# 13      296                          Pulp Fiction (1994)
# 17      356                          Forrest Gump (1994)
# 23      608                                 Fargo (1996)
#
#                          genres        userId    rating     timestamp
# 3                  Comedy|Drama  68604.914894  4.004925  9.397648e+08
# 9          Comedy|Drama|Romance  69455.957398  4.035610  9.670909e+08
# 13  Comedy|Crime|Drama|Thriller  69236.563780  4.174231  1.052293e+09
# 17     Comedy|Drama|Romance|War  69170.493456  4.029000  1.055720e+09
# 23  Comedy|Crime|Drama|Thriller  69005.939869  4.112359  1.041937e+09

# %% [markdown]
# #### 12. Split 'genres' into multiple columns.

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
split_genres = movies['genres'].str.split('|', expand=True)
split_genres.head()
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %% [markdown]
# #### 13. Extract year from title e.g. (1995).

# %%
movies['year'] = movies['title'].str.extract('.*\((.*)\).*', expand=True)
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# #### 14. Select rows based on timestamps later than 2015-02-01.

# %%
tags["Date"]=pd.to_datetime(tags['timestamp'], unit='s')
df_timestamps= tags[tags["Date"]>"2015-02-01"]
df_timestamps.head()
# Out:
#      userId  movieId      tag   timestamp                Date
# 301     318      260    1970s  1424472169 2015-02-20 22:42:49
# 302     318      260  fantasy  1424472169 2015-02-20 22:42:49
# 303     318      260   sci-fi  1424472169 2015-02-20 22:42:49
# 304     318   115149   Action  1424534310 2015-02-21 15:58:30
# 305     318   115149  Revenge  1424534283 2015-02-21 15:58:03

# %% [markdown]
# #### 15. Sort the tags DataFrame based on timestamp.

# %%
dfsort=tags.sort_values(by='Date', ascending=False)
dfsort.head()
# Out:
#         userId  movieId            tag   timestamp                Date
# 339178  102853   115149  russian mafia  1427771352 2015-03-31 03:09:12
# 158780   46072     6058    premonition  1427760764 2015-03-31 00:12:44
# 158763   46072     3409    premonition  1427760726 2015-03-31 00:12:06
# 288375   87797      215         Vienna  1427755801 2015-03-30 22:50:01
# 290535   88044   106782      profanity  1427754096 2015-03-30 22:21:36
